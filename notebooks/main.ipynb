# %%
import sys
import os
import re

import bs4
import pymupdf
import matplotlib.pyplot as plt
import requests

from bs4 import Tag
from PIL import Image

sys.path.append("..")  # Add the parent directory to the Python path

# %%
url = "http://www.fcyt.umss.edu.bo/horarios/"

# %%
response = requests.get(url)
soup = bs4.BeautifulSoup(response.text, "html.parser")

# %%
def get_pdf_link(link: Tag) -> str:
    url = link.get("href")
    return url and url.endswith(".pdf")


urls = [url for url in map(get_pdf_link, soup.find_all("a")) if url]

# %%
semester = soup.find("p", {"class": "titulo2"}).getText()
semester = re.search(r"\d{1,2}-\d{4}", semester).group().replace("-", "/")
semester
# Out:
# '1/2025'

# %%
from datetime import datetime
from src.core.schemas import Career


def get_careers():
    careers: list[Career] = []

    careers_filter: list[Tag] = filter(
        lambda tag: tag.get_text() != "",
        soup.find_all("font", {"size": "3"}),
    )

    for career_tag in careers_filter:
        text: str = career_tag.get_text(strip=True)
        if text.isdigit():
            careers.append(
                Career(
                    madeIn="SCESI UMSS",
                    semester=semester,
                    support="@willypaz243, @ceci, @pablox",
                    path="-".join(semester.split("/")[::-1]),
                )
            )
            continue
        if not careers:
            continue
        current = careers[-1]

        code_and_career = re.search(r"(\d{6})\s(.*)", text)
        if code_and_career:
            current["code"] = int(code_and_career.group(1))
            current["name"] = code_and_career.group(2)
            continue
        link_url = career_tag.find("a")
        if link_url:
            current["url"] = link_url.get("href")
            continue
        updated_at = re.search(r"\d{2}:\d{2}\s\d{2}-\d{2}-\d{4}", text)
        if updated_at:
            date = updated_at.group()
            current["updatet_at"] = datetime.strptime(
                date, "%H:%M %d-%m-%Y"
            ).isoformat()
            current["levels"] = []
            continue

    return careers

# %%
careers = get_careers()
careers_dict = {career["code"]: career for career in careers}

# %%
import json

# %%
print(json.dumps(careers, indent=4))
# Out:
# [
#     {
#         "madeIn": "SCESI UMSS",
#         "semester": "1/2025",
#         "support": "@willypaz243, @ceci, @pablox",
#         "path": "2025-1",
#         "code": 409701,
#         "name": "ALIMENTOS",
#         "url": "http://sagaa.fcyt.umss.edu.bo/pre_academico/horarios/409701.pdf",
#         "updatet_at": "2025-03-04T21:50:00",
#         "levels": []
#     },
#     {
#         "madeIn": "SCESI UMSS",
#         "semester": "1/2025",
#         "support": "@willypaz243, @ceci, @pablox",
#         "path": "2025-1",
#         "code": 399501,
#         "name": "BIOLOGIA",
#         "url": "http://sagaa.fcyt.umss.edu.bo/pre_academico/horarios/399501.pdf",
#         "updatet_at": "2025-03-04T21:50:00",
#         "levels": []
#     },
#     {
#         "madeIn": "SCESI UMSS",
#         "semester": "1/2025",
#         "support": "@willypaz243, @ceci, @pablox",
#         "path": "2025-1",
#         "code": 165221,
#         "name": "BIOTECNOLOGIA",
#         "url": "http://sagaa.fcyt.umss.edu.bo/pre_academico/horarios/165221.pdf",
#         "updatet_at": "2025-03-04T21:50:00",
#         "levels": []
#     },
#     {
#         "madeIn": "SCESI UMSS",
#         "semester": "1/2025",
#         "support": "@willypaz243, @ceci, @pablox",
#         "path": "2025-1",
#         "code": 320902,
#         "name": "CIVIL (NUEVO)",
#         "url": "http://sagaa.fcyt.umss.edu.bo/pre_academico/horarios/320902.pdf",
#         "updatet_at": "2025-03-04T21:50:00",
#         "levels": []
#     },
#     {
#         "madeIn": "SCESI UMSS",
#         "semester": "1/2025",
#         "support": "@willypaz243, @ceci, @pablox",
#         "path": "2025-1",
#         "code": 299701,
#         "name": "ELECTRICA",
#         "url": "http://sagaa.fcyt.umss.edu.bo/pre_academico/horarios/299701.pdf",
#         "updatet_at": "2025-03-04T21:50:00",
#         "levels": []
#     },
#     {
#         "madeIn": "SCESI UMSS",
#         "semester": "1/2025",
#         "support": "@willypaz243, @ceci, @pablox",
#         "path": "2025-1",
#         "code": 650001,
#         "name": "ELECTROMECANICA",
#         "url": "http://sagaa.fcyt.umss.edu.bo/pre_academico/horarios/650001.pdf",
#         "updatet_at": "2025-03-04T21:51:00",
#         "levels": []
#     },
#     {
#         "madeIn": "SCESI UMSS",
#         "semester": "1/2025",
#         "support": "@willypaz243, @ceci, @pablox",
#         "path": "2025-1",
#         "code": 429701,
#         "name": "ELECTRONICA",
#         "url": "http://sagaa.fcyt.umss.edu.bo/pre_academico/horarios/429701.pdf",
#         "updatet_at": "2025-03-04T21:51:00",
#         "levels": []
#     },
#     {
#         "madeIn": "SCESI UMSS",
#         "semester": "1/2025",
#         "support": "@willypaz243, @ceci, @pablox",
#         "path": "2025-1",
#         "code": 166231,
#         "name": "ENERGIA",
#         "url": "http://sagaa.fcyt.umss.edu.bo/pre_academico/horarios/166231.pdf",
#         "updatet_at": "2025-03-04T21:51:00",
#         "levels": []
#     },
#     {
#         "madeIn": "SCESI UMSS",
#         "semester": "1/2025",
#         "support": "@willypaz243, @ceci, @pablox",
#         "path": "2025-1",
#         "code": 760101,
#         "name": "FISICA (DID)",
#         "url": "http://sagaa.fcyt.umss.edu.bo/pre_academico/horarios/760101.pdf",
#         "updatet_at": "2025-03-04T21:51:00",
#         "levels": []
#     },
#     {
#         "madeIn": "SCESI UMSS",
#         "semester": "1/2025",
#         "support": "@willypaz243, @ceci, @pablox",
#         "path": "2025-1",
#         "code": 359201,
#         "name": "FISICA (LIC)",
#         "url": "http://sagaa.fcyt.umss.edu.bo/pre_academico/horarios/359201.pdf",
#         "updatet_at": "2025-03-04T21:52:00",
#         "levels": []
#     },
#     {
#         "madeIn": "SCESI UMSS",
#         "semester": "1/2025",
#         "support": "@willypaz243, @ceci, @pablox",
#         "path": "2025-1",
#         "code": 309801,
#         "name": "INDUSTRIAL",
#         "url": "http://sagaa.fcyt.umss.edu.bo/pre_academico/horarios/309801.pdf",
#         "updatet_at": "2025-03-04T21:52:00",
#         "levels": []
#     },
#     {
#         "madeIn": "SCESI UMSS",
#         "semester": "1/2025",
#         "support": "@willypaz243, @ceci, @pablox",
#         "path": "2025-1",
#         "code": 134111,
#         "name": "INFORMATICA (ING)",
#         "url": "http://sagaa.fcyt.umss.edu.bo/pre_academico/horarios/134111.pdf",
#         "updatet_at": "2025-03-04T21:52:00",
#         "levels": []
#     },
#     {
#         "madeIn": "SCESI UMSS",
#         "semester": "1/2025",
#         "support": "@willypaz243, @ceci, @pablox",
#         "path": "2025-1",
#         "code": 114071,
#         "name": "MATEMATICA (DID)",
#         "url": "http://sagaa.fcyt.umss.edu.bo/pre_academico/horarios/114071.pdf",
#         "updatet_at": "2025-03-04T21:53:00",
#         "levels": []
#     },
#     {
#         "madeIn": "SCESI UMSS",
#         "semester": "1/2025",
#         "support": "@willypaz243, @ceci, @pablox",
#         "path": "2025-1",
#         "code": 439801,
#         "name": "MATEMATICA (ING)",
#         "url": "http://sagaa.fcyt.umss.edu.bo/pre_academico/horarios/439801.pdf",
#         "updatet_at": "2025-03-04T21:53:00",
#         "levels": []
#     },
#     {
#         "madeIn": "SCESI UMSS",
#         "semester": "1/2025",
#         "support": "@willypaz243, @ceci, @pablox",
#         "path": "2025-1",
#         "code": 349701,
#         "name": "MATEMATICA (LIC)",
#         "url": "http://sagaa.fcyt.umss.edu.bo/pre_academico/horarios/349701.pdf",
#         "updatet_at": "2025-03-04T21:53:00",
#         "levels": []
#     },
#     {
#         "madeIn": "SCESI UMSS",
#         "semester": "1/2025",
#         "support": "@willypaz243, @ceci, @pablox",
#         "path": "2025-1",
#         "code": 319801,
#         "name": "MECANICA",
#         "url": "http://sagaa.fcyt.umss.edu.bo/pre_academico/horarios/319801.pdf",
#         "updatet_at": "2025-03-04T21:53:00",
#         "levels": []
#     },
#     {
#         "madeIn": "SCESI UMSS",
#         "semester": "1/2025",
#         "support": "@willypaz243, @ceci, @pablox",
#         "path": "2025-1",
#         "code": 339701,
#         "name": "QUIMICA (ING)",
#         "url": "http://sagaa.fcyt.umss.edu.bo/pre_academico/horarios/339701.pdf",
#         "updatet_at": "2025-03-04T21:54:00",
#         "levels": []
#     },
#     {
#         "madeIn": "SCESI UMSS",
#         "semester": "1/2025",
#         "support": "@willypaz243, @ceci, @pablox",
#         "path": "2025-1",
#         "code": 389701,
#         "name": "QUIMICA (LIC)",
#         "url": "http://sagaa.fcyt.umss.edu.bo/pre_academico/horarios/389701.pdf",
#         "updatet_at": "2025-03-04T21:54:00",
#         "levels": []
#     },
#     {
#         "madeIn": "SCESI UMSS",
#         "semester": "1/2025",
#         "support": "@willypaz243, @ceci, @pablox",
#         "path": "2025-1",
#         "code": 419701,
#         "name": "SISTEMAS",
#         "url": "http://sagaa.fcyt.umss.edu.bo/pre_academico/horarios/419701.pdf",
#         "updatet_at": "2025-02-10T20:05:00",
#         "levels": []
#     },
#     {
#         "madeIn": "SCESI UMSS",
#         "semester": "1/2025",
#         "support": "@willypaz243, @ceci, @pablox",
#         "path": "2025-1",
#         "code": 411702,
#         "name": "SISTEMAS (NUEVO)",
#         "url": "http://sagaa.fcyt.umss.edu.bo/pre_academico/horarios/411702.pdf",
#         "updatet_at": "2025-03-04T21:54:00",
#         "levels": []
#     }
# ]

# %% [markdown]
# # text extraction

# %%
import io

# %%
career  = careers_dict[339701] # quimica

# %%
res  = requests.get(career['url'])
filestream = io.BytesIO(res.content)
pdf_doc = pymupdf.open(stream=filestream, filetype="pdf")

# %%
def extract_all_text(doc):
    text = ""
    for page in doc:
        text += page.get_text() + "\n"
    return text

# %%
def extract_position(text):
    pattern = r"[A-Z]\s\d{7}"

    occurrences = 0
    positions = []
    for match in re.finditer(pattern, text):
        pos = match.start()
        positions.append(pos)
        occurrences += 1
    return positions, occurrences

# %%
def clear_text(text: str) -> str:
    patron = re.compile(r"\bProcesado CPD.*?A\w*\s\d/\d{4}", flags=re.DOTALL)
    cabeceras = re.compile(r"\bNIVEL.*?AULA", flags=re.DOTALL)
    return cabeceras.sub("", patron.sub("", text))

# %%
raw_text = extract_all_text(pdf_doc)
text = clear_text(raw_text)
print(text)
# Out:
# A
# 2008237 ALGEBRA LINEAL Y TEORIA MATRICIAL
# 1
# OMONTE OJALVO JOSE ROBERTO
# JU
# 815 -0945
# 623
# 1
# OMONTE OJALVO JOSE ROBERTO
# VI
# 815 -0945
# 622
# 1
# [TP] SERRANO MENA DIEGO LEONARDO
# SA
# 815 -0945
# 691A
# 2
# SOTO MOREIRA JUAN CARLOS
# LU
# 1415-1545
# 612
# 2
# SOTO MOREIRA JUAN CARLOS
# MA
# 945 -1115
# 661
# 2
# SOTO MOREIRA JUAN CARLOS
# JU
# 1415-1545
# 691F
# 3
# SALINAS PERICON WALTER OSCAR
# GONZALO
# MA
# 815 -0945
# 617B
# 3
# SALINAS PERICON WALTER OSCAR
# GONZALO
# JU
# 1715-1845
# 612
# A
# 2008054 CALCULO I
# 14
# FIORILO LOZADA AMERICO
# LU
# 645 -0815
# 607
# 645 -0815
# 691E
# D
# 2004012 LABORATORIO DE QUIMICA ORGANICA
# 1
# POR DESIGNAR DOCENTE
# LU
# 1415-1845
# 615
# 1
# [TP] POR DESIGNAR DOCENTE
# LU
# 1415-1500
# 615
# 1
# [TP]
# LU
# 1500-1800
# 615
# 2
# POR DESIGNAR DOCENTE
# MA
# 1415-1845
# 615
# 2
# [TP]
# MA
# 1415-1800
# 615
# 3
# POR DESIGNAR DOCENTE
# SA
# 1245-1715
# 616
# D
# 2004053 QUIMICA ORGANICA
# 1
# POR DESIGNAR DOCENTE
# JU
# 645 -0815
# 693C
# 1
# POR DESIGNAR DOCENTE
# VI
# 645 -0815
# 622
# 1
# POR DESIGNAR DOCENTE
# SA
# 645 -0815
# 693C
# 2
# POR DESIGNAR DOCENTE
# LU
# 1115-1245
# 691D
# 2
# POR DESIGNAR DOCENTE
# JU
# 1115-1245
# 691C
# 2
# POR DESIGNAR DOCENTE
# VI
# 945 -1115
# 660
# D
# 2004183 TERMODINAMICA I
# 1
# POR DESIGNAR DOCENTE
# MA
# 1245-1415
# 651
# 1
# POR DESIGNAR DOCENTE
# JU
# 1245-1415
# 691D
# 1
# POR DESIGNAR DOCENTE
# VI
# 1715-1845
# 607
# E
# 2004184 FENOMENOS DE TRANSPORTE A
# 1
# ALFARO DENUS GONZALO
# LU
# 645 -0815
# 693A
# 1
# ALFARO DENUS GONZALO
# MA
# 645 -0815
# 693A
# 1
# ALFARO DENUS GONZALO
# MI
# 645 -0815
# 693A
# E
# 2004169 LABORATORIO DE QUIMICA ANALITICA CUANTITATIVA
# 1
# ARZABE MAURE JOSE OMAR
# LU
# 1415-1845
# 614
# 1
# [TP] HUANCA ALCAZAR MARIELA LIZBETH
# LU
# 1415-1800
# 614
# 2
# [TP]
# JU
# 815 -1200
# 615
#
#
#
# 2
# ESCALERA MEJIA EDWIN
# JU
# 815 -1245
# 615
# 3
# DOMINGUEZ CHURA RAUL AGAPITO
# VI
# 945 -1415
# 615
# 3
# [TP] ROMERO COCA DAYANA NICOLE
# VI
# 945 -1330
# 615
# 4
# ALVAREZ CAERO MARIA MERCEDES
# JU
# 1415-1845
# 615
# 4
# [TP] ROMERO COCA DAYANA NICOLE
# JU
# 1415-1800
# 615
# 5
# ESCALERA MEJIA EDWIN
# LU
# 945 -1415
# 615
# 5
# [TP] HUANCA ALCAZAR MARIELA LIZBETH
# LU
# 945 -1330
# 615
# E
# 2004145 LABORATORIO DE QUIMICA ORGANICA II
# 1
# POR DESIGNAR DOCENTE
# MI
# 1115-1545
# 615
# 1
# [TP]
# MI
# 1115-1500
# 615
# 2
# POR DESIGNAR DOCENTE
# SA
# 815 -1245
# 615
# 2
# [TP]
# SA
# 815 -1200
# 615
# 3
# DAVILA CABRERA MARCELO ARMANDO
# VI
# 1415-1845
# 615
# 3
# [TP] RODRIGUEZ LEDEZMA BELKA RUTH
# VI
# 1415-1800
# 615
# E
# 2004061 QUIMICA ANALITICA
